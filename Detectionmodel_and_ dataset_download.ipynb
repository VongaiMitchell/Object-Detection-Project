# %%
import torch
import torch.nn as nn
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torchvision.models import resnet50

# %%
class DETRWithFasterRCNNBackbone(nn.Module):
    """
    Demo DETR implementation.

    Demo implementation of DETR in minimal number of lines, with the
    following differences wrt DETR in the paper:
    * learned positional encoding (instead of sine)
    * positional encoding is passed at input (instead of attention)
    * fc bbox predictor (instead of MLP)
    The model achieves ~40 AP on COCO val5k and runs at ~28 FPS on Tesla V100.
    Only batch size 1 supported.
    """
    def __init__(self, num_classes, hidden_dim=256, nheads=8,
                 num_encoder_layers=6, num_decoder_layers=6):
        super().__init__()

        # create ResNet-50 backbone
        self.backbone = resnet50()
        del self.backbone.fc

        # create conversion layer
        self.conv = nn.Conv2d(2048, hidden_dim, 1)

        # create a default PyTorch transformer
        self.transformer = nn.Transformer(
            hidden_dim, nheads, num_encoder_layers, num_decoder_layers)

        # prediction heads, one extra class for predicting non-empty slots
        # note that in baseline DETR linear_bbox layer is 3-layer MLP
        self.linear_class = nn.Linear(hidden_dim, num_classes + 1)
        self.linear_bbox = nn.Linear(hidden_dim, 4)

        # output positional encodings (object queries)
        self.query_pos = nn.Parameter(torch.rand(100, hidden_dim))

        # spatial positional encodings
        # note that in baseline DETR we use sine positional encodings
        self.row_embed = nn.Parameter(torch.rand(50, hidden_dim // 2))
        self.col_embed = nn.Parameter(torch.rand(50, hidden_dim // 2))

    def forward(self, inputs):
        # propagate inputs through ResNet-50 up to avg-pool layer
        x = self.backbone.conv1(inputs)
        x = self.backbone.bn1(x)
        x = self.backbone.relu(x)
        x = self.backbone.maxpool(x)

        x = self.backbone.layer1(x)
        x = self.backbone.layer2(x)
        x = self.backbone.layer3(x)
        x = self.backbone.layer4(x)

        # convert from 2048 to 256 feature planes for the transformer
        h = self.conv(x)

        # construct positional encodings
        H, W = h.shape[-2:]
        pos = torch.cat([
            self.col_embed[:W].unsqueeze(0).repeat(H, 1, 1),
            self.row_embed[:H].unsqueeze(1).repeat(1, W, 1),
        ], dim=-1).flatten(0, 1).unsqueeze(1)

        # propagate through the transformer
        h = self.transformer(pos + 0.1 * h.flatten(2).permute(2, 0, 1),
                             self.query_pos.unsqueeze(1)).transpose(0, 1)

        # finally project transformer outputs to class labels and bounding boxes
        return {'pred_logits': self.linear_class(h),
                'pred_boxes': self.linear_bbox(h).sigmoid()}

# %%
class DETRWithFasterRCNNBackbone(nn.Module):
    def __init__(self, num_classes, hidden_dim=256, nheads=8,
                 num_encoder_layers=6, num_decoder_layers=6):
        super().__init__()

        # Create Faster R-CNN backbone
        self.backbone = fasterrcnn_resnet50_fpn(pretrained=True)
        # del self.backbone.fc

        # create conversion layer
        self.conv = nn.Conv2d(2048, hidden_dim, 1)

        # create a default PyTorch transformer
        self.transformer = nn.Transformer(
            hidden_dim, nheads, num_encoder_layers, num_decoder_layers)

        # prediction heads, one extra class for predicting non-empty slots
        # note that in baseline DETR linear_bbox layer is 3-layer MLP
        self.linear_class = nn.Linear(hidden_dim, num_classes + 1)
        self.linear_bbox = nn.Linear(hidden_dim, 4)

        # output positional encodings (object queries)
        self.query_pos = nn.Parameter(torch.rand(100, hidden_dim))

        # spatial positional encodings
        # note that in baseline DETR we use sine positional encodings
        self.row_embed = nn.Parameter(torch.rand(50, hidden_dim // 2))
        self.col_embed = nn.Parameter(torch.rand(50, hidden_dim // 2))


    def forward(self, inputs, targets):
        # Propagate inputs through Faster R-CNN backbone
        features = self.backbone(inputs)
        h = features[0]  # Extract the desired feature level (adjust if needed)

        # Extract boxes and labels from the targets dictionary
        boxes = [target["boxes"] for target in targets]
        labels = [target["labels"] for target in targets]

        # Convert features to the desired shape for transformer input
        H, W = h.shape[-2:]
        h_flatten = h.flatten(2).permute(2, 0, 1)  # Reshape features for transformer input

        # Construct positional encodings
        pos = torch.cat([
            self.col_embed[:W].unsqueeze(0).repeat(H, 1, 1),
            self.row_embed[:H].unsqueeze(1).repeat(1, W, 1),
        ], dim=-1).flatten(0, 1).unsqueeze(1)

        # Propagate through the transformer
        h_with_pos = h_flatten + 0.1 * pos
        h_transformed = self.transformer(h_with_pos, self.query_pos.unsqueeze(1))
        h_transformed = h_transformed.transpose(0, 1)

        # Finally project transformer outputs to class labels and bounding boxes
        transformer_outputs = {
            'pred_logits': self.linear_class(h_transformed),
            'pred_boxes': self.linear_bbox(h_transformed).sigmoid()
        }

        # Compute the loss using the predictions and targets
        loss = compute_loss(transformer_outputs, boxes, labels)  # You need to implement compute_loss

        return loss

# %%
# Create the model
num_classes = 42  # Example: 40
model = DETRWithFasterRCNNBackbone(num_classes=num_classes)

# %% [markdown]
# # **dataset**

# %%
import pandas as pd

# Load class descriptions
class_descriptions_file = '/content/drive/MyDrive/OIDv4_ToolKit/OID/csv_folder/class-descriptions-boxable.csv'
class_descriptions_df = pd.read_csv(class_descriptions_file, header=None, names=['LabelName', 'ClassName'])
class_dict = dict(zip(class_descriptions_df['LabelName'], class_descriptions_df['ClassName']))

# %%
print(class_descriptions_df.head(12))
# Out:
#       LabelName   ClassName
# 0     /m/011k07    Tortoise
# 1   /m/011q46kg   Container
# 2     /m/012074      Magpie
# 3     /m/0120dh  Sea turtle
# 4     /m/01226z    Football
# 5     /m/012n7d   Ambulance
# 6     /m/012w5l      Ladder
# 7     /m/012xff  Toothbrush
# 8     /m/012ysf     Syringe
# 9     /m/0130jx        Sink
# 10    /m/0138tl         Toy
# 11    /m/013y1f       Organ

# %%
from PIL import Image

def get_image_size(image_path):
    with Image.open(image_path) as img:
        return img.size  # Returns a tuple (width, height)

# %%
import os

# Path to the directory containing all class subfolders
data_dir = '/content/drive/MyDrive/OIDv4_ToolKit/OID/Dataset/train/'

# Create a list to store images with annotations
data = []
# Create a mapping from class labels to integer indices
class_labels = []
# Iterate through class subfolders
for class_name in os.listdir(data_dir):
    class_dir = os.path.join(data_dir, class_name)

    # Skip if not a directory
    if not os.path.isdir(class_dir):
        continue
    class_labels.append(class_name)
    # Iterate through images in the class subfolder
    for image_file in os.listdir(class_dir):
        if image_file.endswith('.jpg'):
            image_id = os.path.splitext(image_file)[0]

            image_path = os.path.join(class_dir, image_file)
            image_width, image_height = get_image_size(image_path)

            # Load annotation file for the image
            annotation_file = os.path.join(class_dir, 'Label', f'{image_id}.txt')

            with open(annotation_file, 'r') as f:
                lines = f.readlines()

            bbox_annotations = []
            for line in lines:
                values = line.strip().split()
                class_label = '_'.join(values[:len(values)-4])  # Join class name parts with underscores
                x_min, y_min, x_max, y_max = map(float, values[len(values)-4:])
                bbox_annotations.append({
                    'bbox': [x_min, y_min, x_max, y_max],
                    'category_id': class_label
                })

            data.append({
                'file_name': image_path,
                'image_id': image_id,
                'height': image_height,
                'width': image_width,
                'annotations': bbox_annotations
            })

# Now you can print the first element in the data list
print(data[0])
# Out:
# {'file_name': '/content/drive/MyDrive/OIDv4_ToolKit/OID/Dataset/train/Whisk/0320649bd28a44a1.jpg', 'image_id': '0320649bd28a44a1', 'height': 683, 'width': 1024, 'annotations': [{'bbox': [0.0, 0.0, 430.08, 496.552611], 'category_id': 'Whisk'}]}

# %%
print(data[1])
print(data[4])
# Out:
# {'file_name': '/content/drive/MyDrive/OIDv4_ToolKit/OID/Dataset/train/Whisk/08d454219a3a52b9.jpg', 'image_id': '08d454219a3a52b9', 'height': 1024, 'width': 1024, 'annotations': [{'bbox': [0.0, 69.12, 851.2, 819.84], 'category_id': 'Whisk'}]}
# {'file_name': '/content/drive/MyDrive/OIDv4_ToolKit/OID/Dataset/train/Whisk/17d1b0091181382e.jpg', 'image_id': '17d1b0091181382e', 'height': 683, 'width': 1024, 'annotations': [{'bbox': [193.876992, 84.009, 291.499008, 505.42], 'category_id': 'Whisk'}, {'bbox': [381.611008, 199.43599999999998, 469.675008, 626.994], 'category_id': 'Whisk'}, {'bbox': [531.796992, 206.94899999999998, 621.908992, 631.775], 'category_id': 'Whisk'}, {'bbox': [684.032, 50.541999999999994, 801.451008, 545.034], 'category_id': 'Whisk'}]}

# %% [markdown]
# # **DATASET DOWNLOAD**

# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/facebookresearch/detectron2.git
# Out:
# Cloning into 'detectron2'...
# remote: Enumerating objects: 15188, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 15188 (delta 117), reused 133 (delta 79), pack-reused 14979
# Receiving objects: 100% (15188/15188), 6.22 MiB | 11.60 MiB/s, done.
# Resolving deltas: 100% (10984/10984), done.

# %%
# %cd /content/detectron2
# Out:
# /content/detectron2

# %%
# !python -m pip install -e .

# %% [markdown]
# # **train**

# %%
# Create a mapping from class labels to integer indices
class_to_idx = {class_label: idx for idx, class_label in enumerate(class_labels)}

# %%
class_to_idx
# Out:
# {'Whisk': 0,
#  'Vase': 1,
#  'Toy': 2,
#  'Torch': 3,
#  'Toilet paper': 4,
#  'Tiara': 5,
#  'Teddy bear': 6,
#  'Sunglasses': 7,
#  'Stapler': 8,
#  'Spoon': 9,
#  'Sock': 10,
#  'Screwdriver': 11,
#  'Sandal': 12,
#  'Ruler': 13,
#  'Remote control': 14,
#  'Power plugs and sockets': 15,
#  'Plate': 16,
#  'Pencil case': 17,
#  'Pen': 18,
#  'Personal care': 19,
#  'Necklace': 20,
#  'Mug': 21,
#  'Mobile phone': 22,
#  'Mirror': 23,
#  'Laptop': 24,
#  'Lamp': 25,
#  'Kitchen knife': 26,
#  'Ipod': 27,
#  'Headphones': 28,
#  'Hat': 29,
#  'Glasses': 30,
#  'Glove': 31,
#  'Eraser': 32,
#  'Doll': 33,
#  'Clock': 34,
#  'Candle': 35,
#  'Calculator': 36,
#  'Briefcase': 37,
#  'Book': 38,
#  'Bottle': 39,
#  'Belt': 40,
#  'Ball': 41}

# %%
class CustomDataset(Dataset):
    def __init__(self, data, class_labels, transforms=None):
        self.data = data
        self.class_labels = class_labels
        self.class_to_idx = {class_label: idx for idx, class_label in enumerate(self.class_labels)}
        self.transforms = transforms

    def __len__(self):
        return len(self.data)


    def __getitem__(self, idx):
        img_info = self.data[idx]
        image = Image.open(img_info['file_name']).convert('RGB')

        bbox_annotations = img_info['annotations']
        boxes = []
        labels = []

        for anno in bbox_annotations:
            box = torch.tensor(anno['bbox'], dtype=torch.float32)

            # Preprocess the class label to match the format with underscores
            class_label_with_underscores = anno['category_id']
            class_label = class_label_with_underscores.replace('_', ' ')
            label = torch.tensor(self.class_to_idx[class_label], dtype=torch.int64)

            # label = torch.tensor(self.class_to_idx[anno['category_id']], dtype=torch.int64)
            boxes.append(box)
            labels.append(label)

        target = {
            'boxes': torch.stack(boxes),
            'labels': torch.stack(labels)
        }

        if self.transforms is not None:
            transformed_image = self.transforms(image)
            transformed_target = {
                'boxes': target['boxes'],
                'labels': target['labels']
            }

            return transformed_image, transformed_target

        return image, target

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms


# Define transformations to be applied to both images and targets
transform = transforms.Compose([
    transforms.ToTensor(),  # Convert image to tensor
    # Add more transformations as needed
])

# Create an instance of your custom dataset with transformations
train_dataset = CustomDataset(data, class_labels, transforms=transform)

# Create a DataLoader for training
train_loader = DataLoader(train_dataset, batch_size=2, shuffle=True, collate_fn=lambda x: x)

# %%
# Set up training parameters
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model.to(device)

# %%
# Define optimizer and learning rate scheduler
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# %%
# Print the structure of a batch from the train_loader
for batch_idx, (images, targets) in enumerate(train_loader):
    print(f"Batch {batch_idx + 1}:")
    print("Images:")
    print(images)
    print("Targets:")
    print(targets)
    break  # Print only the first batch for inspection
# Out:
# Batch 1:
# Images:
# (tensor([[[0.7216, 0.7255, 0.7294,  ..., 0.7922, 0.7922, 0.7922],
#          [0.7216, 0.7255, 0.7255,  ..., 0.7843, 0.7843, 0.7843],
#          [0.7255, 0.7216, 0.7216,  ..., 0.7843, 0.7843, 0.7843],
#          ...,
#          [0.6549, 0.6549, 0.6549,  ..., 0.5059, 0.5059, 0.5059],
#          [0.6588, 0.6549, 0.6549,  ..., 0.5020, 0.4980, 0.4980],
#          [0.6588, 0.6549, 0.6549,  ..., 0.4941, 0.4941, 0.4941]],
#
#         [[0.7059, 0.7098, 0.7137,  ..., 0.7647, 0.7647, 0.7647],
#          [0.7059, 0.7098, 0.7098,  ..., 0.7569, 0.7569, 0.7569],
#          [0.7098, 0.7059, 0.7059,  ..., 0.7569, 0.7569, 0.7569],
#          ...,
#          [0.6510, 0.6510, 0.6510,  ..., 0.4745, 0.4745, 0.4745],
#          [0.6549, 0.6510, 0.6510,  ..., 0.4706, 0.4667, 0.4667],
#          [0.6549, 0.6510, 0.6510,  ..., 0.4627, 0.4627, 0.4627]],
#
#         [[0.7020, 0.7059, 0.7098,  ..., 0.7333, 0.7333, 0.7333],
#          [0.7020, 0.7059, 0.7059,  ..., 0.7255, 0.7255, 0.7255],
#          [0.7059, 0.7020, 0.7020,  ..., 0.7255, 0.7255, 0.7255],
#          ...,
#          [0.6431, 0.6431, 0.6431,  ..., 0.4627, 0.4627, 0.4627],
#          [0.6471, 0.6431, 0.6431,  ..., 0.4588, 0.4549, 0.4549],
#          [0.6471, 0.6431, 0.6431,  ..., 0.4510, 0.4510, 0.4510]]]), {'boxes': tensor([[373.6003, 258.3997, 661.6003, 535.2000]]), 'labels': tensor([32])})
# Targets:
# (tensor([[[0.0157, 0.0157, 0.0196,  ..., 0.0118, 0.0118, 0.0078],
#          [0.0235, 0.0118, 0.0157,  ..., 0.0078, 0.0078, 0.0078],
#          [0.0275, 0.0157, 0.0196,  ..., 0.0118, 0.0157, 0.0157],
#          ...,
#          [0.4275, 0.4353, 0.4353,  ..., 0.1725, 0.1765, 0.1804],
#          [0.4392, 0.4431, 0.4431,  ..., 0.1765, 0.1765, 0.1804],
#          [0.4431, 0.4588, 0.4471,  ..., 0.1725, 0.1725, 0.1804]],
#
#         [[0.0157, 0.0157, 0.0196,  ..., 0.0118, 0.0118, 0.0078],
#          [0.0235, 0.0118, 0.0157,  ..., 0.0078, 0.0078, 0.0078],
#          [0.0275, 0.0157, 0.0196,  ..., 0.0118, 0.0157, 0.0157],
#          ...,
#          [0.2314, 0.2314, 0.2314,  ..., 0.0706, 0.0706, 0.0745],
#          [0.2353, 0.2392, 0.2275,  ..., 0.0667, 0.0706, 0.0745],
#          [0.2392, 0.2431, 0.2314,  ..., 0.0627, 0.0627, 0.0706]],
#
#         [[0.0078, 0.0157, 0.0275,  ..., 0.0118, 0.0118, 0.0157],
#          [0.0157, 0.0118, 0.0235,  ..., 0.0078, 0.0078, 0.0157],
#          [0.0196, 0.0157, 0.0275,  ..., 0.0118, 0.0157, 0.0235],
#          ...,
#          [0.0000, 0.0000, 0.0039,  ..., 0.0039, 0.0000, 0.0000],
#          [0.0000, 0.0118, 0.0039,  ..., 0.0118, 0.0039, 0.0078],
#          [0.0039, 0.0196, 0.0118,  ..., 0.0196, 0.0157, 0.0235]]]), {'boxes': tensor([[358.4003,  54.4000, 604.1603, 649.6000]]), 'labels': tensor([25])})

# %%
import torch
import torch.optim as optim

num_epochs = 5
# Training loop
for epoch in range(num_epochs):
    model.train()
    for batch_idx, (images, targets) in enumerate(train_loader):

        # Print the shape and contents of the targets tensor
        print(images)
        print(targets)
        optimizer.zero_grad()
        predictions = model(images)
        loss = criterion(predictions, targets)
        loss.backward()
        optimizer.step()

    # Validation and model evaluation
    model.eval()
    with torch.no_grad():
        for batch_idx, (val_images, val_targets) in enumerate(val_loader):
            val_predictions = model(val_images)
            val_loss = criterion(val_predictions, val_targets)
            # Calculate validation metrics (e.g., mAP) here

    print(f"Epoch [{epoch+1}/{num_epochs}] - Loss: {loss.item()} - Val Loss: {val_loss.item()}")

# %%
# Define loss function and optimizer
criterion = nn.CrossEntropyLoss() + nn.SmoothL1Loss()  # Example combined loss
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def compute_combined_loss(outputs, targets, criterion):
    class_logits = outputs['pred_logits']
    pred_boxes = outputs['pred_boxes']
    target_classes = targets['class_labels']
    target_boxes = targets['bounding_boxes']

    # Compute classification loss
    class_loss = criterion(class_logits, target_classes)

    # Compute regression loss
    reg_loss = criterion(pred_boxes, target_boxes)

    # Combine the losses
    combined_loss = class_loss + reg_loss
    return combined_loss


def evaluate(model, validation_loader):
    model.eval()
    total_loss = 0.0
    metrics = {}  # You can define and calculate your evaluation metrics here

    with torch.no_grad():
        for images, targets in validation_loader:
            outputs = model(images)
            loss = compute_combined_loss(outputs, targets, criterion)
            total_loss += loss.item()
            # Calculate and update metrics

    avg_loss = total_loss / len(validation_loader)
    return avg_loss, metrics

# %%
import torch
import torch.optim as optim

# Create DataLoader and model (using DETRWithPretrainedTransformer)

# Training loop
num_epochs = 10  # Example number of epochs
for epoch in range(num_epochs):
    model.train()  # Set the model to training mode
    for images, targets in train_loader:
        optimizer.zero_grad()  # Zero the gradients

        # Forward pass
        outputs = model(images)

        # Compute loss
        loss = compute_combined_loss(outputs, targets, criterion)  # Implement this function

        # Backpropagation
        loss.backward()  # Compute gradients

        # Update parameters
        optimizer.step()  # Update model weights

    # Validation
    if epoch % 2 == 0:  # Validate every 2 epochs
        model.eval()  # Set the model to evaluation mode
        with torch.no_grad():
            validation_loss, validation_metrics = evaluate(model, validation_loader)  # Implement this function
            print(f"Epoch [{epoch}/{num_epochs}]: Validation Loss: {validation_loss}, Metrics: {validation_metrics}")

# Save the trained model
torch.save(model.state_dict(), "trained_model.pth")

# %%
# Test the model with a sample input
sample_input = torch.rand(1, 3, 224, 224)  # Example input shape
output = model(sample_input)
print(output)

# %% [markdown]
# # **DATASET download**

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 11.05 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# %cd OIDv4_ToolKit
# Out:
# /content/OIDv4_ToolKit

# %%
# !pip3 install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 2)) (1.23.5)
# Collecting awscli (from -r requirements.txt (line 3))
#   Downloading awscli-1.29.32-py3-none-any.whl (4.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 5)) (2.0.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 7)) (4.66.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (4.8.0.76)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->-r requirements.txt (line 1)) (2023.3)
# Collecting botocore==1.31.32 (from awscli->-r requirements.txt (line 3))
#   Downloading botocore-1.31.32-py3-none-any.whl (11.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 56.3 MB/s eta 0:00:00
# Collecting docutils<0.17,>=0.10 (from awscli->-r requirements.txt (line 3))
#   Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.2/548.2 kB 44.8 MB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0 (from awscli->-r requirements.txt (line 3))
#   Downloading s3transfer-0.6.2-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML<6.1,>=3.10 in /usr/local/lib/python3.10/dist-packages (from awscli->-r requirements.txt (line 3)) (6.0.1)
# Collecting colorama<0.4.5,>=0.2.5 (from awscli->-r requirements.txt (line 3))
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting rsa<4.8,>=3.1.2 (from awscli->-r requirements.txt (line 3))
#   Downloading rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from botocore==1.31.32->awscli->-r requirements.txt (line 3))
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting urllib3 (from -r requirements.txt (line 5))
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from rsa<4.8,>=3.1.2->awscli->-r requirements.txt (line 3)) (0.5.0)
# Installing collected packages: urllib3, rsa, jmespath, docutils, colorama, botocore, s3transfer, awscli
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.9
#     Uninstalling rsa-4.9:
#       Successfully uninstalled rsa-4.9
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.18.1
#     Uninstalling docutils-0.18.1:
#       Successfully uninstalled docutils-0.18.1
# Successfully installed awscli-1.29.32 botocore-1.31.32 colorama-0.4.4 docutils-0.16 jmespath-1.0.1 rsa-4.7.2 s3transfer-0.6.2 urllib3-1.26.16

# %%
# !python3 main.py
# Out:
# usage: main.py
#        [-h]
#        [--Dataset /path/to/OID/csv/]
#        [-y]
#        [--classes list of classes [list of classes ...]]
#        [--type_csv 'train' or 'validation' or 'test' or 'all']
#        [--sub Subset of human verified images or machine generated (h or m)]
#        [--image_IsOccluded 1 or 0]
#        [--image_IsTruncated 1 or 0]
#        [--image_IsGroupOf 1 or 0]
#        [--image_IsDepiction 1 or 0]
#        [--image_IsInside 1 or 0]
#        [--multiclasses 0 (default) or 1]
#        [--n_threads [default 20]]
#        [--noLabels]
#        [--limit integer number]
#        <command>
#        'downloader',
#        'visualizer'
#        or
#        'ill_downloader'.
# main.py: error: the following arguments are required: <command> 'downloader', 'visualizer' or 'ill_downloader'.

# %% [markdown]
# **train_set**

# %%
# !python3 main.py downloader -y --classes Whisk Vase Toy Torch "Toilet paper" Tiara "Teddy bear" "Sunglasses" Stapler Spoon Sock "Screwdriver" Sandal Ruler "Remote control" "Power plugs and sockets" Plate "Pencil case" Pen "Personal care" Necklace Mug "Mobile phone" Mirror Laptop Lamp "Kitchen knife" Ipod "Headphones" Hat "Glasses" Glove Eraser Doll Clock Candle Calculator Briefcase Book Bottle Belt Ball --type_csv train --image_IsGroupOf 0 --limit 90
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Whisk.
#    [ERROR] | Missing the class-descriptions-boxable.csv file.
# [DOWNLOAD] | Automatic download.
# ...145%, 0 MB, 38589 KB/s, 0 seconds passed
# [DOWNLOAD] | File class-descriptions-boxable.csv downloaded into OID/csv_folder/class-descriptions-boxable.csv.
#    [ERROR] | Missing the train-annotations-bbox.csv file.
# [DOWNLOAD] | Automatic download.
# ...100%, 1138 MB, 34222 KB/s, 34 seconds passed
# [DOWNLOAD] | File train-annotations-bbox.csv downloaded into OID/csv_folder/train-annotations-bbox.csv.
#
# Whisk
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 154 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:23<00:00,  1.07it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Whisk of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Vase.
#
# Vase
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1044 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:27<00:00,  1.03it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Vase of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Toy.
#
# Toy
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 13483 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:30<00:00,  1.00s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Toy of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Torch.
#
# Torch
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 15 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 15 images in train.
# 100% 15/15 [00:14<00:00,  1.03it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Torch of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Toilet paper.
#
# Toilet paper
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 192 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:29<00:00,  1.01it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Toilet paper of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Tiara.
#
# Tiara
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 321 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:34<00:00,  1.05s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Tiara of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Teddy bear.
#
# Teddy bear
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 907 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:26<00:00,  1.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Teddy bear of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Sunglasses.
#
# Sunglasses
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 12700 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:24<00:00,  1.06it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Sunglasses of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Stapler.
#
# Stapler
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 48 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 48 images in train.
# 100% 48/48 [00:47<00:00,  1.01it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Stapler of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Spoon.
#
# Spoon
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 899 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:26<00:00,  1.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Spoon of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Sock.
#
# Sock
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 500 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:27<00:00,  1.03it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Sock of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Screwdriver.
#
# Screwdriver
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 44 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 44 images in train.
# 100% 44/44 [00:54<00:00,  1.24s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Screwdriver of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Sandal.
#
# Sandal
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1191 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:26<00:00,  1.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Sandal of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Ruler.
#
# Ruler
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 228 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:27<00:00,  1.03it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Ruler of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Remote control.
#
# Remote control
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 183 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:31<00:00,  1.02s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Remote control of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Power plugs and sockets.
#
# Power plugs and sockets
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 133 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:28<00:00,  1.02it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Power plugs and sockets of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Plate.
#
# Plate
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1592 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:36<00:00,  1.07s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Plate of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Pencil case.
#
# Pencil case
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 88 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 88 images in train.
# 100% 88/88 [01:23<00:00,  1.06it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Pencil case of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Pen.
#
# Pen
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 912 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:32<00:00,  1.03s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Pen of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Personal care.
#
# Personal care
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 110 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:28<00:00,  1.02it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Personal care of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Necklace.
#
# Necklace
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 2099 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:25<00:00,  1.05it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Necklace of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Mug.
#
# Mug
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1412 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:26<00:00,  1.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Mug of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Mobile phone.
#
# Mobile phone
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 4128 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:24<00:00,  1.06it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Mobile phone of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Mirror.
#
# Mirror
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 960 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:31<00:00,  1.01s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Mirror of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Laptop.
#
# Laptop
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 4958 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:29<00:00,  1.00it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Laptop of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Lamp.
#
# Lamp
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1401 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:26<00:00,  1.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Lamp of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Kitchen knife.
#
# Kitchen knife
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 239 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:25<00:00,  1.05it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Kitchen knife of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Ipod.
#
# Ipod
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 399 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:41<00:00,  1.13s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Ipod of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Headphones.
#
# Headphones
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 1017 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:32<00:00,  1.03s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Headphones of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Hat.
#
# Hat
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 7226 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:29<00:00,  1.01it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Hat of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Glasses.
#
# Glasses
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 37643 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:27<00:00,  1.03it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Glasses of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Glove.
#
# Glove
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 648 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:26<00:00,  1.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Glove of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Eraser.
#
# Eraser
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 21 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 21 images in train.
# 100% 21/21 [00:34<00:00,  1.64s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Eraser of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Doll.
#
# Doll
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 2980 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:24<00:00,  1.07it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Doll of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Clock.
#
# Clock
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 798 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:26<00:00,  1.04it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Clock of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Candle.
#
# Candle
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 823 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:30<00:00,  1.01s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Candle of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Calculator.
#
# Calculator
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 161 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:30<00:00,  1.01s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Calculator of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Briefcase.
#
# Briefcase
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 105 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:29<00:00,  1.00it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Briefcase of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Book.
#
# Book
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 3613 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:25<00:00,  1.05it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Book of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Bottle.
#
# Bottle
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 9570 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:28<00:00,  1.01it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bottle of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Belt.
#
# Belt
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 333 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:27<00:00,  1.03it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Belt of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Ball.
#
# Ball
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 2456 online images for train.
#     [INFO] | Limiting to 90 images.
#     [INFO] | Download of 90 images in train.
# 100% 90/90 [01:31<00:00,  1.02s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Ball of train.
#     [INFO] | Labels creation completed.

# %% [markdown]
# **val_set**

# %%
# !python3 main.py downloader -y --classes Whisk Vase Toy Torch "Toilet paper" Tiara "Teddy bear" "Sunglasses" Stapler Spoon Sock "Screwdriver" Sandal Ruler "Remote control" "Power plugs and sockets" Plate "Pencil case" Pen "Personal care" Necklace Mug "Mobile phone" Mirror Laptop Lamp "Kitchen knife" Ipod "Headphones" Hat "Glasses" Glove Eraser Doll Clock Candle Calculator Briefcase Book Bottle Belt Ball --type_csv validation --image_IsGroupOf 0 --limit 5
# !python3 main.py downloader -y --classes Apple Orange --type_csv train --image_IsGroupOf 0 --limit 5

# %% [markdown]
# **test set**

# %%
# !python3 main.py downloader -y --classes Whisk Vase Toy Torch "Toilet paper" Tiara "Teddy bear" "Sunglasses" Stapler Spoon Sock "Screwdriver" Sandal Ruler "Remote control" "Power plugs and sockets" Plate "Pencil case" Pen "Personal care" Necklace Mug "Mobile phone" Mirror Laptop Lamp "Kitchen knife" Ipod "Headphones" Hat "Glasses" Glove Eraser Doll Clock Candle Calculator Briefcase Book Bottle Belt Ball --type_csv test --image_IsGroupOf 0 --limit 2
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Whisk.
#    [ERROR] | Missing the test-annotations-bbox.csv file.
# [DOWNLOAD] | Automatic download.
# ...100%, 49 MB, 41184 KB/s, 1 seconds passed
# [DOWNLOAD] | File test-annotations-bbox.csv downloaded into OID/csv_folder/test-annotations-bbox.csv.
#
# Whisk
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 1 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 1 images in test.
# 100% 1/1 [00:01<00:00,  1.75s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Whisk of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Vase.
#
# Vase
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 71 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.16s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Vase of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Toy.
#
# Toy
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 570 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:03<00:00,  1.56s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Toy of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Torch.
#
# Torch
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 6 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.04s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Torch of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Toilet paper.
#
# Toilet paper
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 10 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.06s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Toilet paper of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Tiara.
#
# Tiara
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 42 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.11s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Tiara of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Teddy bear.
#
# Teddy bear
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 61 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:03<00:00,  1.62s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Teddy bear of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Sunglasses.
#
# Sunglasses
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 187 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.12s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Sunglasses of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Stapler.
#
# Stapler
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 1 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 1 images in test.
# 100% 1/1 [00:01<00:00,  1.66s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Stapler of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Spoon.
#
# Spoon
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 91 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.10s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Spoon of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Sock.
#
# Sock
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 68 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:03<00:00,  1.62s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Sock of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Screwdriver.
#
# Screwdriver
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 0 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | All images already downloaded.
#     [INFO] | Creating labels for Screwdriver of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Sandal.
#
# Sandal
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 154 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.04s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Sandal of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Ruler.
#
# Ruler
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 30 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.06s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Ruler of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Remote control.
#
# Remote control
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 19 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.11s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Remote control of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Power plugs and sockets.
#
# Power plugs and sockets
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 34 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:03<00:00,  1.73s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Power plugs and sockets of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Plate.
#
# Plate
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 123 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.24s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Plate of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Pencil case.
#
# Pencil case
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 4 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.09s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Pencil case of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Pen.
#
# Pen
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 79 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.09s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Pen of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Personal care.
#
# Personal care
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 13 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:03<00:00,  1.61s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Personal care of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Necklace.
#
# Necklace
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 141 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.22s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Necklace of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Mug.
#
# Mug
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 75 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.46s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Mug of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Mobile phone.
#
# Mobile phone
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 337 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.10s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Mobile phone of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Mirror.
#
# Mirror
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 58 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:03<00:00,  1.55s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Mirror of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Laptop.
#
# Laptop
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 164 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.06s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Laptop of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Lamp.
#
# Lamp
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 85 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.03s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Lamp of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Kitchen knife.
#
# Kitchen knife
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 55 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:01<00:00,  1.01it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Kitchen knife of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Ipod.
#
# Ipod
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 51 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.38s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Ipod of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Headphones.
#
# Headphones
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 80 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.33s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Headphones of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Hat.
#
# Hat
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 290 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.14s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Hat of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Glasses.
#
# Glasses
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 529 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.08s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Glasses of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Glove.
#
# Glove
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 75 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.21s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Glove of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Eraser.
#
# Eraser
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 1 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 1 images in test.
# 100% 1/1 [00:02<00:00,  2.28s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Eraser of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Doll.
#
# Doll
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 94 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.11s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Doll of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Clock.
#
# Clock
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 44 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.01s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Clock of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Candle.
#
# Candle
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 61 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.20s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Candle of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Calculator.
#
# Calculator
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 45 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:03<00:00,  1.83s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Calculator of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Briefcase.
#
# Briefcase
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 14 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.48s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Briefcase of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Book.
#
# Book
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 57 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.11s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Book of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Bottle.
#
# Bottle
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 370 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.10s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Bottle of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Belt.
#
# Belt
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 25 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.18s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Belt of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Ball.
#
# Ball
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 224 online images for test.
#     [INFO] | Limiting to 2 images.
#     [INFO] | Download of 2 images in test.
# 100% 2/2 [00:02<00:00,  1.49s/it]
#     [INFO] | Done!
#     [INFO] | Creating labels for Ball of test.
#     [INFO] | Labels creation completed.

# %%
import shutil

# Source folder path (in Colab environment)
source_folder = '/content/OIDv4_ToolKit2'

# Destination folder path in Google Drive
destination_folder = '/content/drive/MyDrive/'

# Move the folder and its contents
shutil.move(source_folder, destination_folder)
# Out:
# '/content/drive/MyDrive/OIDv4_ToolKit2'

# %%
# !zip -r OID.zip OID

# %%
from google.colab import files
files.download('OID.zip')
